# %%
from diviner import file_utils as fu

# %%
tstr = '2014041404'

# %%
l1a = fu.get_clean_l1a(tstr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-658be875f6c6> in <module>()
# ----> 1 l1a = fu.get_clean_l1a(tstr)
#
# /u/paige/maye/src/diviner/file_utils.pyc in get_clean_l1a(timestr)
#     770 def get_clean_l1a(timestr):
#     771     l1afile = L1ADataFile.from_timestr(timestr)
# --> 772     return l1afile.open()
#     773
#     774
#
# AttributeError: 'NoneType' object has no attribute 'open'

# %%
l1a = fu.L1ADataFile('/u/paige/maye/l1a_data/2014041610_L1A.TAB')

# %%
df = l1a.open()

# %%
df.b3_11.plot()

# %%
from mpld3 import enable_notebook
enable_notebook()
