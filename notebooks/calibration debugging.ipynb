# %%
import pandas
pandas.__version__
# Out:
# '0.13.0'

# %%
import sys
sys.path.append('/u/paige/maye/src')

# %%
from diviner import calib, file_utils as fu, plot_utils as pu
reload(calib)
reload(pu)
reload(fu)
# Out:
# <module 'diviner.file_utils' from '/u/paige/maye/src/diviner/file_utils.pyc'>

# %%
fu.l1adatapath
# Out:
# '/luna1/marks/feidata/DIV:opsL1A/data'

# %%
# tstr = '2012121714'
tstr = '2009123114'
l1a = fu.L1ADataFile.from_timestr(tstr)
#df = l1a.open()
df = fu.open_and_accumulate(l1a.fname)
# Out:
# Appending 2009123113 on the left.
# Appending 2009123115 on the right.

# %%
c = calib.Calibrator(df)

# %%
# %load_ext line_profiler

# %%
# %lprun -f calib.RBBTable.get_tb c.calibrate()

# %%
# %timeit c.calibrate()
c.calibrate()

# %%
c.gains
# Out:
#                                a3_01     a3_02     a3_03     a3_04     a3_05  \
# 2009-12-31 13:10:07.470500 -0.000993 -0.000928 -0.000919 -0.000938 -0.000945
# 2009-12-31 13:20:23.934000 -0.000994 -0.000930 -0.000921 -0.000940 -0.000947
# 2009-12-31 13:30:40.397000 -0.000993 -0.000929 -0.000919 -0.000938 -0.000945
# 2009-12-31 13:40:56.860000 -0.000992 -0.000927 -0.000918 -0.000937 -0.000944
# 2009-12-31 13:51:13.323000 -0.000991 -0.000927 -0.000918 -0.000936 -0.000943
# 2009-12-31 14:01:29.784500 -0.000992 -0.000928 -0.000918 -0.000938 -0.000944
# 2009-12-31 14:06:45.183000 -0.000993 -0.000928 -0.000919 -0.000938 -0.000945
# 2009-12-31 14:16:59.596000 -0.000993 -0.000928 -0.000919 -0.000938 -0.000945
# 2009-12-31 14:27:18.104500 -0.000992 -0.000927 -0.000918 -0.000937 -0.000944
# 2009-12-31 14:37:34.565000 -0.000993 -0.000928 -0.000919 -0.000938 -0.000945
# 2009-12-31 14:47:51.026000 -0.000993 -0.000928 -0.000919 -0.000937 -0.000945
# 2009-12-31 14:58:07.487000 -0.000993 -0.000928 -0.000919 -0.000938 -0.000945
# 2009-12-31 15:08:23.959000 -0.000992 -0.000927 -0.000918 -0.000937 -0.000944
# 2009-12-31 15:18:40.420500 -0.000992 -0.000927 -0.000918 -0.000937 -0.000944
# 2009-12-31 15:29:17.363000 -0.000992 -0.000927 -0.000918 -0.000937 -0.000944
# 2009-12-31 15:39:13.344000 -0.000992 -0.000928 -0.000919 -0.000937 -0.000945
# 2009-12-31 15:49:27.758000 -0.000992 -0.000928 -0.000918 -0.000938 -0.000945
#
#                                a3_06     a3_07     a3_08     a3_09     a3_10  \
# 2009-12-31 13:10:07.470500 -0.000920 -0.000932 -0.000920 -0.000924 -0.000935
# 2009-12-31 13:20:23.934000 -0.000921 -0.000934 -0.000923 -0.000926 -0.000937
# 2009-12-31 13:30:40.397000 -0.000920 -0.000932 -0.000921 -0.000924 -0.000935
# 2009-12-31 13:40:56.860000 -0.000919 -0.000931 -0.000920 -0.000923 -0.000935
# 2009-12-31 13:51:13.323000 -0.000919 -0.000931 -0.000920 -0.000923 -0.000934
# 2009-12-31 14:01:29.784500 -0.000920 -0.000932 -0.000921 -0.000924 -0.000935
# 2009-12-31 14:06:45.183000 -0.000920 -0.000932 -0.000922 -0.000924 -0.000935
# 2009-12-31 14:16:59.596000 -0.000920 -0.000932 -0.000921 -0.000924 -0.000935
# 2009-12-31 14:27:18.104500 -0.000917 -0.000916 -0.000916 -0.000910 -0.000892
# 2009-12-31 14:37:34.565000 -0.000917 -0.000916 -0.000917 -0.000911 -0.000893
# 2009-12-31 14:47:51.026000 -0.000917 -0.000916 -0.000916 -0.000911 -0.000892
# 2009-12-31 14:58:07.487000 -0.000918 -0.000917 -0.000917 -0.000911 -0.000893
# 2009-12-31 15:08:23.959000 -0.000917 -0.000916 -0.000916 -0.000911 -0.000892
# 2009-12-31 15:18:40.420500 -0.000917 -0.000916 -0.000917 -0.000910 -0.000892
# 2009-12-31 15:29:17.363000 -0.000917 -0.000916 -0.000916 -0.000910 -0.000892
# 2009-12-31 15:39:13.344000 -0.000918 -0.000916 -0.000917 -0.000911 -0.000893
# 2009-12-31 15:49:27.758000 -0.000918 -0.000916 -0.000917 -0.000911 -0.000893
#
#
# 2009-12-31 13:10:07.470500 ...
# 2009-12-31 13:20:23.934000 ...
# 2009-12-31 13:30:40.397000 ...
# 2009-12-31 13:40:56.860000 ...
# 2009-12-31 13:51:13.323000 ...
# 2009-12-31 14:01:29.784500 ...
# 2009-12-31 14:06:45.183000 ...
# 2009-12-31 14:16:59.596000 ...
# 2009-12-31 14:27:18.104500 ...
# 2009-12-31 14:37:34.565000 ...
# 2009-12-31 14:47:51.026000 ...
# 2009-12-31 14:58:07.487000 ...
# 2009-12-31 15:08:23.959000 ...
# 2009-12-31 15:18:40.420500 ...
# 2009-12-31 15:29:17.363000 ...
# 2009-12-31 15:39:13.344000 ...
# 2009-12-31 15:49:27.758000 ...
#
# [17 rows x 147 columns]

# %%
groups = calib.get_calib_blocks(df, 'calib')

# %%
cb = calib.CalBlock(groups[1])

# %%
import pandas as pd

# %%
offsets = pd.DataFrame(cb.get_offsets()).T

# %%
offsets.index = [cb.offsets_time]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-74dce2500100> in <module>()
# ----> 1 offsets.index = [cb.offsets_time]
#
# /u/paige/maye/anaconda/lib/python2.7/site-packages/pandas-0.13.0-py2.7-linux-x86_64.egg/pandas/core/generic.pyc in __setattr__(self, name, value)
#    1611                 existing = getattr(self, name)
#    1612                 if isinstance(existing, Index):
# -> 1613                     object.__setattr__(self, name, value)
#    1614                 elif name in self._info_axis:
#    1615                     self[name] = value
#
# /u/paige/maye/anaconda/lib/python2.7/site-packages/pandas-0.13.0-py2.7-linux-x86_64.egg/pandas/lib.so in pandas.lib.AxisProperty.__set__ (pandas/lib.c:30413)()
#
# /u/paige/maye/anaconda/lib/python2.7/site-packages/pandas-0.13.0-py2.7-linux-x86_64.egg/pandas/core/generic.pyc in _set_axis(self, axis, labels)
#     392
#     393     def _set_axis(self, axis, labels):
# --> 394         self._data.set_axis(axis, labels)
#     395         self._clear_item_cache()
#     396
#
# /u/paige/maye/anaconda/lib/python2.7/site-packages/pandas-0.13.0-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in set_axis(self, axis, value, maybe_rename, check_axis)
#    1997
#    1998     def set_axis(self, axis, value, maybe_rename=True, check_axis=True):
# -> 1999         cur_axis, value = self._set_axis(axis, value, check_axis)
#    2000
#    2001         if axis == 0:
#
# /u/paige/maye/anaconda/lib/python2.7/site-packages/pandas-0.13.0-py2.7-linux-x86_64.egg/pandas/core/internals.pyc in _set_axis(self, axis, value, check_axis)
#    1990             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    1991                              'new values have %d elements' % (len(cur_axis),
# -> 1992                                                               len(value)))
#    1993
#    1994         self.axes[axis] = value
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 1 elements
