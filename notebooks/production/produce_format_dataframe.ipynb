# %%
from pds.core.parser import Parser
import StringIO
import os
from collections import namedtuple
import diviner

# %%
def get_columns(fname):
    parser = Parser()
    with open(fname) as f:
        rdrformat = f.readlines()
    s = ''
    for line in rdrformat:
        if line == '\n':
            sio = StringIO.StringIO(s)
            yield parser.parse(sio)['COLUMN']
            s = ''
        s += line

# %%
fname = os.path.join(diviner.__path__[0], 'data','rdr_format.txt')

# %%
dic = {}
for col in get_columns(fname):
    dic[col['NAME']] = col

# %%
rdr_format = pd.DataFrame.from_dict(dic).T

# %%
from collections import OrderedDict, namedtuple
def get_columns_from_rdr_columns(fname=None):
    "Generator to yield items of the rdr_columns file."
    RDRColumn = namedtuple('RDRColumn', 'colno, colname, type_format, desc')
    if not fname:
        fname = os.path.join(diviner.__path__[0], 'data','rdr_columns.txt')
    with open(fname) as f:
        data = f.readlines()
    # use this counter to know when 4 items were collected
    counter = 0
    container = []
    for line in data:
        if not line.strip():
            continue
        container.append(line.strip())
        counter += 1
        if counter == 4:
            yield RDRColumn(*container)
            counter = 0
            container = []


def get_formats_dict():
    dic = OrderedDict()
    for col in get_columns_from_rdr_columns():
        dic[col.colname] = col
    return dic

# %%
ordered = get_formats_dict()

# %%
rdr_columns = pd.DataFrame.from_dict(ordered).T

# %%
rdr_columns.head()
# Out:
#          0        1             2  \
# date     1     date  Character 13
# utc      2      utc  Character 14
# jdate    3    jdate     Real 17.9
# orbit    4    orbit     Integer 5
# sundist  5  sundist      Real 7.5
#
#                                                          3
# date     Date at the midpoint of observation (SCET, UTC...
# utc      Time at the midpoint of observation (SCET, UTC...
# jdate    Julian Date at the midpoint of observation (SC...
# orbit                            Orbit number.  0 to 99999
# sundist  The distance from the center of the moon to th...
#
# [5 rows x 4 columns]

# %%
rdr_columns.columns = ['COLUMN_NUMBER','NAME','FORMAT','DESCRIPTION']

# %%
rdr_format = rdr_format.convert_objects(convert_numeric=True)

# %%
rdr_format.sort('COLUMN_NUMBER',inplace=True)

# %%
rdr_format.head()
# Out:
#          BYTES  COLUMN_NUMBER      DATA_TYPE  \
# date        11              1      CHARACTER
# utc         12              2      CHARACTER
# jdate       17              3     ASCII_REAL
# orbit        5              4  ASCII_INTEGER
# sundist      7              5     ASCII_REAL
#
#                                                DESCRIPTION  INVALID_CONSTANT  \
# date     "Date at the midpoint of observation (SCET, UT...             -9998
# utc      "Time at the midpoint of observation (SCET, UT...             -9998
# jdate    "Julian Date at the midpoint of observation (S...             -9998
# orbit                           "Orbit number. 0 to 99999"             -9998
# sundist  "The distance from the center of the moon to t...             -9998
#
#             NAME  START_BYTE  UNKNOWN_CONSTANT
# date        date           2             -9999
# utc          utc          17             -9999
# jdate      jdate          32             -9999
# orbit      orbit          51             -9999
# sundist  sundist          58             -9999
#
# [5 rows x 8 columns]

# %%
joined = rdr_format.join(rdr_columns, lsuffix='_format', rsuffix='_columns')

# %%
joined.ix['qge']
# Out:
# BYTES                                                                    3
# COLUMN_NUMBER_format                                                    32
# DATA_TYPE                                                    ASCII_INTEGER
# DESCRIPTION_format       "Quality Flag for Geometry. A 3-digit decimal ...
# INVALID_CONSTANT                                                     -9998
# NAME_format                                                            qge
# START_BYTE                                                             333
# UNKNOWN_CONSTANT                                                     -9999
# COLUMN_NUMBER_columns                                                  NaN
# NAME_columns                                                           NaN
# FORMAT                                                                 NaN
# DESCRIPTION_columns                                                    NaN
# Name: qge, dtype: object

# %%
joined.NAME_columns == joined.NAME_format
# Out:
# date          True
# utc           True
# jdate         True
# orbit         True
# sundist       True
# sunlat        True
# sunlon        True
# sclk          True
# sclat         True
# sclon         True
# scrad         True
# scalt         True
# el_cmd        True
# az_cmd        True
# af            True
# orientlat     True
# orientlon     True
# c             True
# det           True
# vlookx        True
# vlooky        True
# vlookz        True
# radiance      True
# tb            True
# clat          True
# clon          True
# cemis         True
# csunzen       True
# csunazi       True
# cloctime      True
# qca          False
# qge          False
# dtype: bool

# %%
joined.index
# Out:
# Index([u'date', u'utc', u'jdate', u'orbit', u'sundist', u'sunlat', u'sunlon', u'sclk', u'sclat', u'sclon', u'scrad', u'scalt', u'el_cmd', u'az_cmd', u'af', u'orientlat', u'orientlon', u'c', u'det', u'vlookx', u'vlooky', u'vlookz', u'radiance', u'tb', u'clat', u'clon', u'cemis', u'csunzen', u'csunazi', u'cloctime', u'qca', u'qge'], dtype='object')

# %%
joined.index.name = 'colname'

# %%
joined.to_csv('joined_format_file.csv')

# %% [markdown]
# ### Read in exported CSV file

# %%
import diviner
import os
fname = os.path.join(diviner.__path__[0],'data','joined_format_file.csv')
pd.read_csv(fname)
# Out:
#       colname  COLUMN_NUMBER  BYTES      DATA_TYPE  START_BYTE        FORMAT  \
# 0        date              1     11      CHARACTER           2  Character 13
# 1         utc              2     12      CHARACTER          17  Character 14
# 2       jdate              3     17     ASCII_REAL          32     Real 17.9
# 3       orbit              4      5  ASCII_INTEGER          51     Integer 5
# 4     sundist              5      7     ASCII_REAL          58      Real 7.5
# 5      sunlat              6      8     ASCII_REAL          67      Real 8.5
# 6      sunlon              7      9     ASCII_REAL          77      Real 9.5
# 7        sclk              8     16     ASCII_REAL          88     Real 16.5
# 8       sclat              9      9     ASCII_REAL         106      Real 9.5
# 9       sclon             10      9     ASCII_REAL         117      Real 9.5
# 10      scrad             11     11     ASCII_REAL         128     Real 11.5
# 11      scalt             12     11     ASCII_REAL         141     Real 11.5
# 12     el_cmd             13      7     ASCII_REAL         154      Real 7.3
# 13     az_cmd             14      7     ASCII_REAL         163      Real 7.3
# 14         af             15      4  ASCII_INTEGER         172     Integer 4
# 15  orientlat             16      9     ASCII_REAL         178      Real 9.5
# 16  orientlon             17      9     ASCII_REAL         189      Real 9.5
# 17          c             18      1  ASCII_INTEGER         200     Integer 1
# 18        det             19      3  ASCII_INTEGER         203     Integer 3
# 19     vlookx             20      9     ASCII_REAL         208      Real 9.6
# 20     vlooky             21      9     ASCII_REAL         219      Real 9.6
# 21     vlookz             22      9     ASCII_REAL         230      Real 9.6
# 22   radiance             23     10     ASCII_REAL         241     Real 10.4
# 23         tb             24      8     ASCII_REAL         253      Real 8.3
# 24       clat             25      9     ASCII_REAL         263      Real 9.5
# 25       clon             26      9     ASCII_REAL         274      Real 9.5
# 26      cemis             27      9     ASCII_REAL         285      Real 9.5
# 27    csunzen             28      9     ASCII_REAL         296      Real 9.5
# 28    csunazi             29      9     ASCII_REAL         307      Real 9.5
# 29   cloctime             30      8     ASCII_REAL         318      Real 8.5
# 30        qca             31      3  ASCII_INTEGER         328           NaN
# 31        qge             32      3  ASCII_INTEGER         333           NaN
#
#     UNKNOWN_CONSTANT  INVALID_CONSTANT  \
# 0              -9999             -9998
# 1              -9999             -9998
# 2              -9999             -9998
# 3              -9999             -9998
# 4              -9999             -9998
# 5              -9999             -9998
# 6              -9999             -9998
# 7              -9999             -9998
# 8              -9999             -9998
# 9              -9999             -9998
# 10             -9999             -9998
# 11             -9999             -9998
# 12             -9999             -9998
# 13             -9999             -9998
# 14             -9999             -9998
# 15             -9999             -9998
# 16             -9999             -9998
# 17             -9999             -9998
# 18             -9999             -9998
# 19             -9999             -9998
# 20             -9999             -9998
# 21             -9999             -9998
# 22             -9999             -9998
# 23             -9999             -9998
# 24             -9999             -9998
# 25             -9999             -9998
# 26             -9999             -9998
# 27             -9999             -9998
# 28             -9999             -9998
# 29             -9999             -9998
# 30             -9999             -9998
# 31             -9999             -9998
#
#                                   DESCRIPTION_columns  \
# 0   Date at the midpoint of observation (SCET, UTC...
# 1   Time at the midpoint of observation (SCET, UTC...
# 2   Julian Date at the midpoint of observation (SC...
# 3                           Orbit number.  0 to 99999
# 4   The distance from the center of the moon to th...
# 5      Subsolar Latitude (deg).  -1.7 to 1.7 degrees.
# 6   Subsolar East Longitude (deg). 0.00000 to 360....
# 7   Spacecraft clock at midpoint of observation (s...
# 8   Subspacecraft Latitude (deg).  -90.00000 to 90...
# 9   Subspacecraft East Longitude (deg).  0 to 360....
# 10  Distance from the center of moon to the spacec...
# 11  Distance from the surface of the moon to the s...
# 12        Last Elevation Command (deg).  0 to 270.000
# 13           Last Azimuth Command (deg). 0 to 270.000
# 14  Activity Flag.  Range is -999 to 999.  See App...
# 15  Orientation Latitude (deg).  The latitudinal c...
# 16  Orientation Longitude (deg).  The east longitu...
# 17                     Diviner Channel Number. 1 to 9
# 18                   Diviner Detector Number. 1 to 21
# 19  The X component of the Diviner Look Unit Vecto...
# 20  The Y component of the Diviner Look Unit Vecto...
# 21  The Z component of the Diviner Look Unit Vecto...
# 22  Calibrated Radiance (W m**-2 sr**-1).  The rea...
# 23  Calibrated Brightness Temperature (K).   Excep...
# 24  Latitude of FOV center (deg).   Undefined if o...
# 25  East longitude of FOV center (deg).  Undefined...
# 26  Emission Angle at FOV center (deg).   This is ...
# 27  Solar Zenith angle at FOV center (deg). This i...
# 28  Solar Azimuth Angle at FOV Center (deg).  0 de...
# 29  Local time at FOV Center (hours past midnight)...
# 30                                                NaN
# 31                                                NaN
#
#                                    DESCRIPTION_format
# 0   "Date at the midpoint of observation (SCET, UT...
# 1   "Time at the midpoint of observation (SCET, UT...
# 2   "Julian Date at the midpoint of observation (S...
# 3                          "Orbit number. 0 to 99999"
# 4   "The distance from the center of the moon to t...
# 5            "Subsolar Latitude (deg). E.g. -1.54333"
# 6   "Subsolar East Longitude (deg). 0.00000 to 360...
# 7   "Spacecraft clock at midpoint of observation (...
# 8   "Subspacecraft Latitude (deg). -90.00000 to 90...
# 9   "Subspacecraft East Longitude (deg). 0 to 360....
# 10  "Distance from the center of moon to the space...
# 11  "Distance from the surface of the moon to the ...
# 12       "Last Elevation Command (deg). 0 to 270.000"
# 13         "Last Azimuth Command (deg). 0 to 270.000"
# 14  "Activity Flag. See Appendix B of DLRE RDR SIS...
# 15  "Orientation Latitude (deg). The latitudinal c...
# 16  "Orientation Longitude (deg). The east longitu...
# 17                   "Diviner Channel Number. 1 to 9"
# 18                 "Diviner Detector Number. 1 to 21"
# 19  "The X component of the Diviner Look Unit Vect...
# 20  "The Y component of the Diviner Look Unit Vect...
# 21  "The Z component of the Diviner Look Unit Vect...
# 22  "Calibrated Radiance (W m**-2 sr**-1). Range i...
# 23  "Calibrated Brightness Temperature (K). Except...
# 24  "Latitude of FOV center (deg). Undefined if of...
# 25  "East longitude of FOV center (deg). Undefined...
# 26  "Emission Angle at FOV center (deg). Undefined...
# 27  "Solar Zenith angle at FOV center (deg). Undef...
# 28  "Solar Azimuth Angle at FOV Center (deg). 0 de...
# 29  "Local time at FOV Center (hours past midnight...
# 30  "Quality Flag for Calibration. A 3-digit decim...
# 31  "Quality Flag for Geometry. A 3-digit decimal ...
#
# [32 rows x 10 columns]
