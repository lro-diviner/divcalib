# %%
df = pd.read_csv("./file_stats.csv", index_col=0)

# %%
df
# Out:
#       nfiles_per_yr  nhours_per_yr     ratio
# 2009           4297           8760  0.490525
# 2010           8585           8760  0.980023
# 2011           8679           8760  0.990753
# 2012           8719           8784  0.992600
# 2013           8697           8760  0.992808
# 2014           8652           8760  0.987671
# 2015           8760           8760  1.000000
# 2016           8784           8784  1.000000
# 2017           8760           8760  1.000000
# 2018           8737           8760  0.997374
# 2019           3557           8760  0.406050

# %%
ratio_mean = df.loc[2010:2018].mean()['ratio']
ratio_mean
# Out:
# 0.9934700354595183

# %%
df.dtypes
# Out:
# nfiles_per_yr      int64
# nhours_per_yr      int64
# ratio            float64
# dtype: object

# %%
# %matplotlib widget

# %%
fig, ax = plt.subplots()
df.ratio.plot(style='*-', ax=ax)
ax.axhline(1)
ax.axhline(ratio_mean, ls='--')
ax.text(2010, ratio_mean, "Average(2010--2018)", verticalalignment='bottom')
ax.set_xlabel('Year')
ax.set_ylabel("Fraction L1A available")
ax.set_title("Diviner L1A availability")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Diviner L1A availability')

# %%
plt.gcf().savefig("/u/paige/maye/diviner_L1A_availability.pdf")

# %%
df.median(
# Out:
# A     3.041370
# B    -9.169320
# C   -10.187865
# D     3.298608
# dtype: float64

# %%
import pandas as pd, numpy as np
idx = pd.date_range('1/1/2000', periods=1000)
df  = pd.DataFrame(np.random.randn(1000, 4), index=idx, columns=list('ABCD')).cumsum()

import hvplot.pandas
df.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)
