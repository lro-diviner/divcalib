# %%
cd ~/Dropbox/data/diviner/ground_calib/
# Out:
# /Users/klay6683/Dropbox/data/diviner/ground_calib

# %%
ls
# Out:
# 2008011018_hsk.csv      all_data.h5             diode_temperatures.csv  house_keeping.h5
# 2008011201_hsk.csv      calib.log               gc_a6_b1_b2_b3.h5       telB_ground_calib.h5

# %%
diode_temps = pd.read_csv('diode_temperatures.csv')
diode_temps.head()
# Out:
#     UTC Date  UTC Time  Variable BB Base (K)  Variable BB Rib (K)  \
# 0  1/10/2008  20:52:20             40.459287            28.446792
# 1  1/10/2008  20:52:50             39.487987            27.955813
# 2  1/10/2008  20:53:20             38.508092            27.564601
# 3  1/10/2008  20:53:50             37.549627            27.176733
# 4  1/10/2008  20:54:20             36.482253            26.838486
#
#    Fixed BB Base (K)  Fixed BB Rib (K)
# 0          90.712624         90.336777
# 1          90.742845         90.446738
# 2          90.742845         90.586690
# 3          90.783141         90.676660
# 4          90.783141         90.736640

# %%
diode_temps['UTC'] = pd.to_datetime(diode_temps['UTC Date'] + ' ' + diode_temps['UTC Time'])

# %%
diode_temps.set_index('UTC', inplace=True)

# %%
diode_temps.drop(['UTC Date', 'UTC Time'], axis=1, inplace=True)

# %%
# %matplotlib nbagg
# Out:
# /Users/klay6683/miniconda3/envs/py27/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
diode_temps.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
pd.read_hdf('all_data.h5', 'df')
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# <ipython-input-9-0f87ab1a5e8d> in <module>()
# ----> 1 pd.read_hdf('all_data.h5', 'df')
#
# /Users/klay6683/miniconda3/envs/py27/lib/python2.7/site-packages/pandas-0.16.2+627.gc16e3b8-py2.7-macosx-10.5-x86_64.egg/pandas/io/pytables.pyc in read_hdf(path_or_buf, key, **kwargs)
#     318         # can't auto open/close if we are using an iterator
#     319         # so delegate to the iterator
# --> 320         store = HDFStore(path_or_buf, **kwargs)
#     321         auto_close = True
#     322
#
# /Users/klay6683/miniconda3/envs/py27/lib/python2.7/site-packages/pandas-0.16.2+627.gc16e3b8-py2.7-macosx-10.5-x86_64.egg/pandas/io/pytables.pyc in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     411         self._fletcher32 = fletcher32
#     412         self._filters = None
# ...
