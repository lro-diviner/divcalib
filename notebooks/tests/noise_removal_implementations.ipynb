# %%
from diviner import file_utils as fu

# %%
cd ~/src/diviner
# Out:
# /u/paige/maye/src/diviner

# %%
old = fu.read_l1a_data('2012011401_L1A.TAB')

# %%
corrected = fu.read_l1a_data('2012011401_L1A.TAB.corrected')

# %%
cdet = 'a5_11'
diff = old[cdet]-corrected[cdet]
diff.plot()

# %%
diff.describe()
# Out:
# count    28128.000000
# mean        -0.005447
# std          0.532213
# min         -6.250000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          6.050000
# Name: a5_11, dtype: float64
