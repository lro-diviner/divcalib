# %%
from diviner import file_utils as fu

# %%
def cols_to_descriptor(iterable):
    out = 'Diviner pipes descriptor file\n'
    for col in iterable:
        out += "'{0}' '{0}'\n".format(col)
    out += "'end' 'end'\n"
    return out

# %%
obs = fu.DivObs('2011120100')

# %%
l1a = obs.get_l1a()

# %%
print cols_to_descriptor(l1a.columns[:5])
# Out:
# Diviner pipes descriptor file
# 'q' 'q'
# 'sclk' 'sclk'
# 'sounding' 'sounding'
# 'from_pkt' 'from_pkt'
# 'pkt_count' 'pkt_count'

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ~
# Out:
# /u/paige/maye

# %%
desctext = cols_to_descriptor(l1a.columns[:4])
with open('bintest.des','w') as f:
    f.write(desctext)

# %%
l1a[l1a.columns[:4]].head()
# Out:
#                             q          sclk  sounding  from_pkt
# 2011-12-01 00:00:01.619000  0  3.443904e+08         1      9695
# 2011-12-01 00:00:01.747000  0  3.443904e+08         2      9695
# 2011-12-01 00:00:01.875000  0  3.443904e+08         3      9696
# 2011-12-01 00:00:02.003000  0  3.443904e+08         4      9696
# 2011-12-01 00:00:02.131000  0  3.443904e+08         5      9697
#
# [5 rows x 4 columns]

# %%
# %%sh
# /bin/tcsh -c "cat bintest.des bintest.np|pprint"
# Out:
#           0.000000000  344390401.598000050          1.000000000       9695.000000000
#           0.000000000  344390401.726000011          2.000000000       9695.000000000
#           0.000000000  344390401.854000032          3.000000000       9696.000000000
#           0.000000000  344390401.981999993          4.000000000       9696.000000000
#           0.000000000  344390402.110000014          5.000000000       9697.000000000
#           0.000000000  344390402.238000035          6.000000000       9698.000000000
#           0.000000000  344390402.365999997          7.000000000       9698.000000000
#           0.000000000  344390402.494000018          8.000000000       9699.000000000
#           0.000000000  344390402.621999979          9.000000000       9699.000000000
#           0.000000000  344390402.750000000         10.000000000       9700.000000000
#           0.000000000  344390402.878000021         11.000000000       9701.000000000
# ...

# %%
arr
# Out:
# array([[ 0.,  1.,  2.],
#        [ 3.,  4.,  5.]])

# %%
l1a.head()
# Out:
#                             q          sclk  sounding  from_pkt  pkt_count  \
# 2011-12-01 00:00:01.619000  0  3.443904e+08         1      9695        NaN
# 2011-12-01 00:00:01.747000  0  3.443904e+08         2      9695        NaN
# 2011-12-01 00:00:01.875000  0  3.443904e+08         3      9696        NaN
# 2011-12-01 00:00:02.003000  0  3.443904e+08         4      9696        NaN
# 2011-12-01 00:00:02.131000  0  3.443904e+08         5      9697        NaN
#
#                             safing  safed  freezing  frozen  rolling  dumping  \
# 2011-12-01 00:00:01.619000     NaN    NaN       NaN     NaN      NaN      NaN
# 2011-12-01 00:00:01.747000     NaN    NaN       NaN     NaN      NaN      NaN
# 2011-12-01 00:00:01.875000     NaN    NaN       NaN     NaN      NaN      NaN
# 2011-12-01 00:00:02.003000     NaN    NaN       NaN     NaN      NaN      NaN
# 2011-12-01 00:00:02.131000     NaN    NaN       NaN     NaN      NaN      NaN
#
# ...
