# %% [markdown]
# # Creating HDF file

# %%
root = '/luna1/marks/feidata/DIV:instTestRdr/data'

# %%
from diviner import file_utils as fu
from diviner import plot_utils as pu
from diviner import calib

# %%
rdr = fu.RDRReader(root+'/2014052822_RDR.TAB')

# %%
df = rdr.open()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5315625 entries, 2014-05-28 22:00:00.023000 to 2014-05-28 22:59:59.954000
# Data columns (total 32 columns):
# jdate        float64
# orbit        int64
# sundist      float64
# sunlat       float64
# sunlon       float64
# sclk         float64
# sclat        float64
# sclon        float64
# scrad        float64
# scalt        float64
# el_cmd       float64
# az_cmd       float64
# af           int64
# orientlat    float64
# orientlon    float64
# c            int64
# det          int64
# vlookx       float64
# vlooky       float64
# vlookz       float64
# radiance     float64
# tb           float64
# clat         float64
# clon         float64
# cemis        float64
# csunzen      float64
# csunazi      float64
# cloctime     float64
# qca          int64
# qge          int64
# qmi          int64
# elonge       float64
# dtypes: float64(25), int64(7)

# %%
ll /raid1/maye/rdr_data
# Out:
# lrwxrwxrwx 1 maye 38 Jun 28  2013 /raid1/maye/rdr_data -> /raid1/u/marks/feidata/DIV:opsRdr/data/

# %%
df.to_hdf('/raid1/maye/rdr_test_data/2014052822_RDR.h5','df')

# %% [markdown]
# # Loading data from HDF and analyses

# %%
df = pd.read_hdf('/raid1/maye/rdr_test_data/2014052822_RDR.h5','df')

# %%
df.columns
# Out:
# Index([u'jdate', u'orbit', u'sundist', u'sunlat', u'sunlon', u'sclk', u'sclat', u'sclon', u'scrad', u'scalt', u'el_cmd', u'az_cmd', u'af', u'orientlat', u'orientlon', u'c', u'det', u'vlookx', u'vlooky', u'vlookz', u'radiance', u'tb', u'clat', u'clon', u'cemis', u'csunzen', u'csunazi', u'cloctime', u'qca', u'qge', u'qmi', u'elonge'], dtype='object')

# %%
dfresampled = df.resample('1s')

# %%
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#
#         <style>
#             /* BEGIN /u/paige/maye/anaconda/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
#                 /*! jQuery UI - v1.10.0 - 2013-01-17
#                 * http://jqueryui.com
#                 * Includes: jquery.ui.core.css, jquery.ui.accordion.css, jquery.ui.autocomplete.css, jquery.ui.button.css, jquery.ui.datepicker.css, jquery.ui.dialog.css, jquery.ui.menu.css, jquery.ui.progressbar.css, jquery.ui.resizable.css, jquery.ui.selectable.css, jquery.ui.slider.css, jquery.ui.spinner.css, jquery.ui.tabs.css, jquery.ui.tooltip.css, jquery.ui.theme.css
# ...

# %%
from bokeh.plotting import line, show, hold, legend, scatter

# %%
hold(True)
plotter = line
plotter(dfresampled.index.to_series(), dfresampled.elonge, 
     x_axis_type='datetime', color='red', legend='elonge')
plotter(dfresampled.index.to_series(), dfresampled.el_cmd,
     x_axis_type='datetime', color='green', legend='elev')
plotter(dfresampled.index.to_series(), dfresampled.az_cmd,
     x_axis_type='datetime', color='blue', legend='azim')
legend()
show()
# Out:
# <script type="text/javascript">
#         $(function() {
#             var modelid = "22ebd145-3458-4139-b7b8-78ba073be0ed";
#             var modeltype = "Plot";
#             var elementid = "6c218515-2b90-4a4d-bb46-dcf49e92cf17";
#             Bokeh.logger.info("Realizing plot:")
#             Bokeh.logger.info(" - modeltype: Plot");
#             Bokeh.logger.info(" - modelid: 22ebd145-3458-4139-b7b8-78ba073be0ed");
#             Bokeh.logger.info(" - elementid: 6c218515-2b90-4a4d-bb46-dcf49e92cf17");
# ...

# %%
from diviner import file_utils as fu

# %%
df2 = fu.prepare_data(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-faabd9312a89> in <module>()
# ----> 1 df2 = fu.prepare_data(df)
#
# /u/paige/maye/src/diviner/diviner/data_prep.pyc in prepare_data(df_in)
#      78     # df = index_by_time(df_in)
#      79     # df[df == -9999.0] = nan
# ---> 80     df_in.last_el_cmd.replace([np.nan], inplace=True)
#      81     df_in.last_az_cmd.replace([np.nan], inplace=True)
#      82     df_in.moving.replace([np.nan], inplace=True)
#
# /u/paige/maye/src/pandas/pandas/core/generic.pyc in __getattr__(self, name)
#    1916                 return self[name]
#    1917             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1918                                  (type(self).__name__, name))
#    1919
#    1920     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'last_el_cmd'

# %%
if not 'last_el_cmd' in df.columns:
    df.rename(columns = {'el_cmd':'last_el_cmd',
                         'az_cmd':'last_az_cmd'},
              inplace=True)

# %%
for col in df.columns:
    if col.endswith('_cmd'):
        print col
# Out:
# last_el_cmd
# last_az_cmd

# %%
df2 = fu.prepare_data(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-faabd9312a89> in <module>()
# ----> 1 df2 = fu.prepare_data(df)
#
# /u/paige/maye/src/diviner/diviner/data_prep.pyc in prepare_data(df_in)
#      80     df_in.last_el_cmd.replace([np.nan], inplace=True)
#      81     df_in.last_az_cmd.replace([np.nan], inplace=True)
# ---> 82     df_in.moving.replace([np.nan], inplace=True)
#      83     return df_in
#      84
#
# /u/paige/maye/src/pandas/pandas/core/generic.pyc in __getattr__(self, name)
#    1916                 return self[name]
#    1917             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1918                                  (type(self).__name__, name))
#    1919
#    1920     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'moving'

# %%
df.columns
# Out:
# Index([u'jdate', u'orbit', u'sundist', u'sunlat', u'sunlon', u'sclk', u'sclat', u'sclon', u'scrad', u'scalt', u'last_el_cmd', u'last_az_cmd', u'af', u'orientlat', u'orientlon', u'c', u'det', u'vlookx', u'vlooky', u'vlookz', u'radiance', u'tb', u'clat', u'clon', u'cemis', u'csunzen', u'csunazi', u'cloctime', u'qca', u'qge', u'qmi', u'elonge', u'sdtype'], dtype='object')

# %%
obs = fu.DivObs('2014052822')

# %%
rdr1 = obs.get_rdrs()
# Out:
# ---------------------------------------------------------------------------
# RDRS_NotFoundError                        Traceback (most recent call last)
# <ipython-input-60-99ba95f7406a> in <module>()
# ----> 1 rdr1 = obs.get_rdrs()
#
# /u/paige/maye/src/diviner/diviner/file_utils.pyc in get_rdrs(self)
#     231
#     232     def get_rdrs(self):
# --> 233         return RDRS_Reader(self.rdrsfname.path).open()
#     234
#     235     def copy(self):
#
# /u/paige/maye/src/diviner/diviner/file_utils.pyc in __init__(self, fname)
#     992             self.df = fname_to_df(fname, dtypes, keys)
#     993         except IOError as e:
# --> 994             raise self.exception(e)
#     995
#     996     def parse_times(self):
#
# RDRS_NotFoundError: [Errno 2] No such file or directory: '/luna6/marks/rdrs_data/2014052822.rdrs'

# %%
df.columns
# Out:
# Index([u'jdate', u'orbit', u'sundist', u'sunlat', u'sunlon', u'sclk', u'sclat', u'sclon', u'scrad', u'scalt', u'last_el_cmd', u'last_az_cmd', u'af', u'orientlat', u'orientlon', u'c', u'det', u'vlookx', u'vlooky', u'vlookz', u'radiance', u'tb', u'clat', u'clon', u'cemis', u'csunzen', u'csunazi', u'cloctime', u'qca', u'qge', u'qmi', u'elonge', u'sdtype'], dtype='object')
