# %%
from diviner import file_utils as fu, plot_utils as pu, calib

# %%
# %matplotlib inline

# %%
tstr = '2010010100'
tstr = '2010020100'
tstr = '2010040100'
l1a = fu.open_and_accumulate(tstr)

# %%
rdr2 = calib.Calibrator(l1a)
# Out:
# INFO:diviner.calib:Calibrating from 2010-03-31 23:00:00.703000 to 2010-04-01 02:00:01.938000.

# %%
rdr2.calibrate()
# Out:
# INFO:diviner.calib:Performing radiance correction on 2010-03-31 23:00:00.703000

# %%
obs = fu.DivObs('2010040100')
rdr1 = obs.get_rdrs()

# %%
from scipy.interpolate import interp1d, UnivariateSpline as Spline
target_times = rdr2.df.index
column = rdr2.offsets.b1_11
all_times = target_times.values.astype('float64')
column_times = column.index.values.astype('float64')

def interpolate_calpoints(k, s):
    spline = Spline(column_times, column, s=s, k=k)
    res = pd.Series(spline(all_times),index=target_times)
    rdr2.offsets_interp.b1_11.plot(style='.', markersize=1)
    rdr2.offsets.b1_11.plot(style='*', markersize=12)
    res.plot(label='k={}, s={}'.format(k, s))

# %%
from IPython.html.widgets import interactive

# %%
interactive(interpolate_calpoints, k=(1,3), s=(0.0, 1.5,0.1 ))

# %%
fit1.plot(label='k=1')
fit2.plot(label='k=2')
fit3.plot(label='k=3')
legend()

# %%
fit.plot()
