# %%
from diviner import metadata_plotter

# %%
df = metadata_plotter.get_all_df('fpa_temp')

# %%
df.columns
# Out:
# Index([u'bb_1_temp', u'last_eqx_prediction', u'dumping', u'ticks_pkt_start', u'from_pkt', u'safing', u'error_count', u'min_15v', u'solar_target_temp', u'fpb_temp', u'sounding', u'hybrid_temp', u'solar_base_temp', u'ost_index', u'commands_executed', u'baffle_a_temp_cyc', u'bb_1_temp_cyc', u'last_el_cmd', u'fpa_temp_cyc', u'fpa_temp', u'last_time_command', u'temp_fault', u'bb_2_temp', u'plu_15v', u'el_actuator_temp', u'az_actuator_temp', u'baffle_a_temp', u'est_index', u'safed', u'last_az_cmd', u'fpb_temp_cyc', u'freezing', u'ticks_at_sc_time', u'baffle_b_temp_cyc', u'plu_5v', u'error_time', u'rolling', u'pkt_count', u'oba_1_temp_cyc', u'error_id', u'commands_rejected', u'commands_received', u'frozen', u'sclk', u'sc_time_subs', u'baffle_b_temp', u'oba_2_temp', u'moving', u'sst_index', u'oba_1_temp', u'yoke_temp', u'sc_time_secs', u'sdtype', u'calib_block_labels', u'sv_block_labels', u'bb_block_labels', u'st_block_labels', u'is_spaceview', u'is_bbview', u'is_stview', u'is_moving', u'is_
# ...

# %%
col = df.columns[0]
df[col].plot(title=col)

# %%
t_cols = df.filter(regex='temp').columns

# %%
df.filter(regex='5v').columns
# Out:
# Index([u'min_15v', u'plu_15v', u'plu_5v'], dtype='object')

# %%
unique_t_cols = list(set([i.split('_')[0] for i in t_cols]))

# %%
# for tcol in unique_t_cols:
for tcol in df.filter(regex='5v').columns:
#     cols_to_plot = [i for i in t_cols if i.startswith(tcol)]
    df[[tcol]].plot(title=tcol)
    savefig('./plots/hk_'+tcol+'.png', dpi=200)

# %%
from diviner import metadata
reload(metadata)
# Out:
# <module 'diviner.metadata' from '/u/paige/maye/src/diviner/metadata.pyc'>

# %%
metadata.produce_store_file('201311')
# Out:
# Found 657 files.
# Concatting...
# Polishing...
# Writing to store...
# Done.
