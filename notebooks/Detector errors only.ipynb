# %%
mpl.style.use('ggplot')

# %%
tstr1 = '2009072712'
tstr2 = '2013052119'
df = fu.DivObs(tstr).get_l1a()

# %%
df.b3_11.plot()
title('Counts of b3_11')

# %%
df.b3_11.std()
# Out:
# 4.8343257917641997

# %%
from scipy.signal import detrend

# %%
detrended = detrend(df.b3_10)

# %%
detrended.std()
# Out:
# 3.3591004367677773

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-07-27 12:00:00.898000, ..., 2009-07-27 13:00:01.214000]
# Length: 28128, Freq: None, Timezone: None

# %%
detrended = detrend(df['2009-07-27 12':'2009-07-27 12:20'].b3_10)

# %%
plot(detrended)

# %%
detrended.std()
# Out:
# 2.4041766095225996

# %%
detrend(df['2007-09-27 12:35':'2007-09-27 12:45'].b3_10).std()
