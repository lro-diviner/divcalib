# %%
import pandas as pd
from diviner import calib
from diviner import file_utils as fu
from diviner import plot_utils as pu
pd.__version__
# Out:
# '0.12.0-1175-g0477cd1'

# %%
l1a = fu.L1ADataFile.from_timestr('20110416')

# %%
l1a.open()
# Out:
#                             q          sclk  sounding  from_pkt  pkt_count  \
# 2011-04-16 00:00:01.297000  0  3.246048e+08         1      1739        NaN
# 2011-04-16 00:00:01.425000  0  3.246048e+08         2      1739        NaN
# 2011-04-16 00:00:01.553000  0  3.246048e+08         3      1740        NaN
# 2011-04-16 00:00:01.681000  0  3.246048e+08         4      1740        NaN
# 2011-04-16 00:00:01.809000  0  3.246048e+08         5      1741        NaN
# 2011-04-16 00:00:01.937000  0  3.246048e+08         6      1742        NaN
# 2011-04-16 00:00:02.065000  0  3.246048e+08         7      1742        NaN
# 2011-04-16 00:00:02.193000  0  3.246048e+08         8      1743      21474
# 2011-04-16 00:00:02.321000  0  3.246048e+08         9      1743        NaN
# 2011-04-16 00:00:02.449000  0  3.246048e+08        10      1744        NaN
# 2011-04-16 00:00:02.577000  0  3.246048e+08        11      1745        NaN
# 2011-04-16 00:00:02.705000  0  3.246048e+08        12      1745        NaN
# 2011-04-16 00:00:02.833000  0  3.246048e+08        13      1746        NaN
# 2011-04-16 00:00:02.961000  0  3.246048e+08        14      1746        NaN
# 2011-04-16 00:00:03.089000  0  3.246048e+08        15      1747        NaN
# 2011-04-16 00:00:03.217000  0  3.246048e+08        16      1748        NaN
# 2011-04-16 00:00:03.345000  0  3.246048e+08         1      1749        NaN
# 2011-04-16 00:00:03.473000  0  3.246048e+08         2      1749        NaN
# 2011-04-16 00:00:03.601000  0  3.246048e+08         3      1750        NaN
# 2011-04-16 00:00:03.729000  0  3.246048e+08         4      1750        NaN
# 2011-04-16 00:00:03.857000  0  3.246048e+08         5      1751        NaN
# 2011-04-16 00:00:03.985000  0  3.246048e+08         6      1752        NaN
# 2011-04-16 00:00:04.113000  0  3.246048e+08         7      1752        NaN
# 2011-04-16 00:00:04.241000  0  3.246048e+08         8      1753      21475
# 2011-04-16 00:00:04.369000  0  3.246048e+08         9      1753        NaN
# 2011-04-16 00:00:04.497000  0  3.246048e+08        10      1754        NaN
# 2011-04-16 00:00:04.625000  0  3.246048e+08        11      1755        NaN
# 2011-04-16 00:00:04.753000  0  3.246048e+08        12      1755        NaN
# 2011-04-16 00:00:04.881000  0  3.246048e+08        13      1756        NaN
# 2011-04-16 00:00:05.009000  0  3.246048e+08        14      1756        NaN
# 2011-04-16 00:00:05.137000  0  3.246048e+08        15      1757        NaN
# 2011-04-16 00:00:05.265000  0  3.246048e+08        16      1758        NaN
# 2011-04-16 00:00:05.393000  0  3.246048e+08         1      1759        NaN
# 2011-04-16 00:00:05.521000  0  3.246048e+08         2      1759        NaN
# 2011-04-16 00:00:05.649000  0  3.246048e+08         3      1760        NaN
# 2011-04-16 00:00:05.777000  0  3.246048e+08         4      1760        NaN
# 2011-04-16 00:00:05.905000  0  3.246048e+08         5      1761        NaN
# 2011-04-16 00:00:04.881000        NaN        NaN ...
# 2011-04-16 00:00:05.009000        NaN        NaN ...
# 2011-04-16 00:00:05.137000        NaN        NaN ...
# 2011-04-16 00:00:05.265000        NaN        NaN ...
# 2011-04-16 00:00:05.393000          2          1 ...
# 2011-04-16 00:00:05.521000        NaN        NaN ...
# 2011-04-16 00:00:05.649000        NaN        NaN ...
# 2011-04-16 00:00:05.777000        NaN        NaN ...
# 2011-04-16 00:00:05.905000        NaN        NaN ...
# 2011-04-16 00:00:06.033000        NaN        NaN ...
# 2011-04-16 00:00:06.161000        NaN        NaN ...
# 2011-04-16 00:00:06.289000        NaN        NaN ...
# 2011-04-16 00:00:06.417000        NaN        NaN ...
# 2011-04-16 00:00:06.545000        NaN        NaN ...
# 2011-04-16 00:00:06.673000        NaN        NaN ...
# 2011-04-16 00:00:06.801000        NaN        NaN ...
# 2011-04-16 00:00:06.929000        NaN        NaN ...
# 2011-04-16 00:00:07.057000        NaN        NaN ...
# 2011-04-16 00:00:07.185000        NaN        NaN ...
# 2011-04-16 00:00:07.313000        NaN        NaN ...
# 2011-04-16 00:00:07.441000          2          1 ...
# 2011-04-16 00:00:07.569000        NaN        NaN ...
# 2011-04-16 00:00:07.697000        NaN        NaN ...
# 2011-04-16 00:00:07.825000        NaN        NaN ...
# 2011-04-16 00:00:07.953000        NaN        NaN ...
# 2011-04-16 00:00:08.081000        NaN        NaN ...
# 2011-04-16 00:00:08.209000        NaN        NaN ...
# 2011-04-16 00:00:08.337000        NaN        NaN ...
# 2011-04-16 00:00:08.465000        NaN        NaN ...
# 2011-04-16 00:00:08.593000        NaN        NaN ...
# 2011-04-16 00:00:08.721000        NaN        NaN ...
# 2011-04-16 00:00:08.849000        NaN        NaN ...
#                                   ...        ...
#
# [28128 rows x 257 columns]

# %%
df.b3_11.plot()

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56240 entries, 2011-04-01 00:00:01.978000 to 2011-04-01 02:00:00.697000
# Columns: 252 entries, sclk to is_calib
# dtypes: bool(6), float64(241), int32(4), int64(1)

# %%
df.calib_block_labels.value_counts()
# Out:
# 0     51632
# 3       736
# 12      352
# 11      352
# 10      352
# 9       352
# 8       352
# 7       352
# 6       352
# 5       352
# 4       352
# 2       352
# 1       352
# dtype: int64

# %%
df.is_calib.value_counts()
# Out:
# False    53200
# True      3040
# dtype: int64

# %%
df.is_moving.value_counts()
# Out:
# False    54096
# True      2144
# dtype: int64

# %%
df.is_stview.value_counts() # that 80 is one st_view
# Out:
# False    56160
# True        80
# dtype: int64

# %% [markdown]
# the reason for the moving data after the last sv_view being cut-off abruptly, is the commanded azimuth and elevation not fitting to any calib pointing definition. That's why the moving part at the end is in no block definition, even so the blocks contain all other moving data.

# %%
pu.plot_calib_block(df,'calib_block_labels',6)

# %%
df[df.calib_block_labels==6].index[-1]
# Out:
# <Timestamp: 2011-04-01 00:59:00.841000>

# %%
df.index[-1]
# Out:
# <Timestamp: 2011-04-01 02:00:00.697000>

# %%
df.sv_block_labels.value_counts().sort_index()
# Out:
# 0     53248
# 1       128
# 2       112
# 3       128
# 4       112
# 5       128
# 6       112
# 7       112
# 8       128
# 9       112
# 10      128
# 11      112
# 12      128
# 13      112
# 14      128
# 15      112
# 16      128
# 17      112
# 18      128
# 19      112
# 20      128
# 21      112
# 22      128
# 23      112
# 24      128
# 25      112
# dtype: int64

# %%
df.bb_block_labels.value_counts()
# Out:
# 0     54896
# 12      112
# 11      112
# 10      112
# 9       112
# 8       112
# 7       112
# 6       112
# 5       112
# 4       112
# 3       112
# 2       112
# 1       112
# dtype: int64

# %%
pu.plot_calib_block(df,'bb_block_labels',6)

# %%
t1 = df[df.calib_block_labels==2].index[0]

# %%
t2 = df[df.calib_block_labels==4].index[-1]

# %%
df.ix[t1:t2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9968 entries, 2011-04-01 00:17:12.135999 to 2011-04-01 00:38:27.928999
# Columns: 252 entries, sclk to is_calib
# dtypes: bool(6), float64(241), int32(4), int64(1)

# %%
df.filter(regex='block_labels')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56240 entries, 2011-04-01 00:00:01.978000 to 2011-04-01 02:00:00.697000
# Data columns (total 4 columns):
# calib_block_labels    56240  non-null values
# sv_block_labels       56240  non-null values
# bb_block_labels       56240  non-null values
# st_block_labels       56240  non-null values
# dtypes: int32(4)

# %%
ax = df.filter(regex='block_labels').plot(linewidth=2)
df.filter(regex='is_').plot(ax=ax,linewidth=2)

# %%
pu.plot_calib_block(df,'calib_block_labels',3,det='b1_11')

# %% [markdown]
# the calib block labels contain moving data as well, to be able to mark sv and bb views together as 1 block if they happen together. that's why I have to subtract the moving data if I want to compare the resulting number with df.is_calib entries.

# %%
df[(df.calib_block_labels >0) & (df.moving==1)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1568 entries, 2011-04-01 00:06:53.631999 to 2011-04-01 01:55:26.259000
# Columns: 252 entries, sclk to is_calib
# dtypes: bool(6), float64(241), int32(4), int64(1)

# %%
df.calib_block_labels.value_counts().sort_index()[1:].sum()
# Out:
# 4608

# %%
2496-896
# Out:
# 1600

# %% [markdown]
# this is the same as the value of all is_calib data (which does not contain moving data)

# %%
df.is_calib.value_counts()
# Out:
# False    53200
# True      3040
# dtype: int64

# %%
pump = fu.Div247DataPump('201104')

# %%
df = pump.get_n_hours(1)
# Out:
# /Users/maye/data/diviner/div247/201104/2011040100.div247

# %%
df.groupby(['calib_block_labels','is_spaceview']).a3_11.mean()
# Out:
# calib_block_labels  is_spaceview
# 0                   False           22366.915404
# 1                   False           23167.416667
#                     True            23815.556250
# 2                   False           23167.223958
#                     True            23805.956250
# 3                   False           23375.290323
#                     True            23808.483333
# 4                   False           22879.781250
#                     True            23825.062500
# 5                   False           22551.218750
#                     True            23854.287500
# 6                   False           22421.588542
#                     True            23884.593750
# Name: a3_11, dtype: float64

# %%
def ptp(arr):
    return arr.max() - arr.min()

# %%
df.groupby(['calib_block_labels','is_spaceview'])['a3_11','a4_11'].agg([ptp,'size'])
# Out:
#                                  a3_11         a4_11
#                                    ptp   size    ptp   size
# calib_block_labels is_spaceview
# 0                  False          5052  25616   2357  25616
# 1                  False          1198    192    608    192
#                    True             14    160     16    160
# 2                  False          1181    192    597    192
#                    True             16    160     13    160
# 3                  False          1180    496    596    496
#                    True             28    240     22    240
# 4                  False          2081    192    942    192
#                    True             15    160     15    160
# 5                  False          3933    192   1922    192
#                    True             23    160     25    160
# 6                  False          4497    192   2170    192
#                    True             21    160     23    160

# %%
grouped = df.groupby(['calib_block_labels'])

# %%
def myfunc(arr):
    local_sv = df.ix[arr.index]['is_spaceview']
    return arr[local_sv].mean()

# %%
grouped.a3_11.agg(myfunc)
# Out:
# calib_block_labels
# 0                              NaN
# 1                     23815.556250
# 2                     23805.956250
# 3                     23808.483333
# 4                     23825.062500
# 5                     23854.287500
# 6                     23884.593750
# Name: a3_11, dtype: float64

# %%
df.groupby(['calib_block_labels','is_spaceview']).a3_11.mean()
# Out:
# calib_block_labels  is_spaceview
# 0                   False           22366.915404
# 1                   False           23167.416667
#                     True            23815.556250
# 2                   False           23167.223958
#                     True            23805.956250
# 3                   False           23375.290323
#                     True            23808.483333
# 4                   False           22879.781250
#                     True            23825.062500
# 5                   False           22551.218750
#                     True            23854.287500
# 6                   False           22421.588542
#                     True            23884.593750
# Name: a3_11, dtype: float64

# %%
block1 = df[df.calib_block_labels==1]

# %%
block1[block1.is_spaceview].a3_11.mean()
# Out:
# 23815.556250000001

# %%
grouped.a3_11.mean()
# Out:
# calib_block_labels
# 0                     22366.915404
# 1                     23462.025568
# 2                     23457.556818
# 3                     23516.548913
# 4                     23309.454545
# 5                     23143.522727
# 6                     23086.590909
# Name: a3_11, dtype: float64

# %%
grouped[['a3_11']].transform(myfunc)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 28112 entries, 2011-04-01 00:00:01.978000 to 2011-04-01 01:00:00.234000
# Data columns (total 1 columns):
# a3_11    2496  non-null values
# dtypes: float64(1)

# %%
def get_sv(df, column='a3_11'):
    dfhere = df[df.is_spaceview]
    return dfhere.filter(regex='_11').mean()

# %%
grouped.apply(get_sv)
# Out:
#                            a1_11         a2_11         a3_11         a4_11  \
# calib_block_labels
# 0                            NaN           NaN           NaN           NaN
# 1                   22368.262500  22556.006250  23815.556250  23195.531250
# 2                   22400.506250  22561.437500  23805.956250  23193.868750
# 3                   22419.620833  22580.833333  23808.483333  23205.541667
# 4                   22422.918750  22610.450000  23825.062500  23229.750000
# 5                   22400.556250  22643.075000  23854.287500  23261.537500
# 6                   22355.493750  22664.037500  23884.593750  23288.312500
#
#                           a5_11        a6_11         b1_11        b2_11  \
# calib_block_labels
# 0                           NaN          NaN           NaN          NaN
# 1                   23189.60625  26347.68750  30025.150000  28159.81250
# 2                   23188.24375  26346.76875  30028.937500  28155.71875
# 3                   23200.80000  26348.53750  30037.404167  28161.56250
# 4                   23223.81875  26355.98750  30053.531250  28181.92500
# 5                   23254.67500  26366.75000  30070.225000  28211.90000
# 6                   23278.93750  26374.55000  30074.768750  28232.74375
#
#                            b3_11
# calib_block_labels
# 0                            NaN
# 1                   27702.425000
# 2                   27700.368750
# 3                   27706.604167
# 4                   27722.343750
# 5                   27743.643750
# 6                   27757.256250

# %%
grouped.a3_11.mean()
# Out:
# calib_block_labels
# 0                     22366.915404
# 1                     23462.025568
# 2                     23457.556818
# 3                     23516.548913
# 4                     23309.454545
# 5                     23143.522727
# 6                     23086.590909
# Name: a3_11, dtype: float64

# %%
s = pd.Series(df.index)

# %%
fu.timediff(s)
# Out:
# 0                NaT
# 1    00:00:00.127999
# 2    00:00:00.128001
# 3    00:00:00.128000
# 4    00:00:00.128000
# 5    00:00:00.127999
# 6    00:00:00.128001
# 7    00:00:00.128000
# 8    00:00:00.127999
# 9    00:00:00.128000
# 10   00:00:00.128001
# 11   00:00:00.128000
# 12   00:00:00.127999
# 13   00:00:00.128000
# 14   00:00:00.128001
# ...
# 28097   00:00:00.128000
# 28098   00:00:00.128000
# 28099   00:00:00.128000
# 28100   00:00:00.128000
# 28101   00:00:00.128000
# 28102   00:00:00.128000
# 28103   00:00:00.128000
# 28104   00:00:00.128000
# 28105   00:00:00.128000
# 28106   00:00:00.128000
# 28107   00:00:00.128000
# 28108   00:00:00.128000
# 28109   00:00:00.128000
# 28110   00:00:00.128000
# 28111   00:00:00.128000
# Length: 28112, dtype: timedelta64[ns]

# %%
reload(calib)
# Out:
# <module 'calib' from 'calib.py'>

# %%
stframe = calib.get_calib_block(df,'st')[1]

# %%
stframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 272 entries, 2011-04-01 00:27:20.399999 to 2011-04-01 00:27:55.088000
# Columns: 252 entries, sclk to is_calib
# dtypes: bool(6), float64(241), int32(4), int64(1)

# %%
pu.plot_calib_block(df,'st',1)

# %%
pu.plot_calib_block(df,'sv',1)

# %%
stframe.calib_block_labels.value_counts()
# Out:
# 3    272
# dtype: int64

# %%
pu.plot_calib_block(df,'calib',3)

# %%
calibdf = df[df.is_calib]

# %%
pu.plot_calib_block(df, 'calib',3)

# %%
reload(pu)
# Out:
# <module 'plot_utils' from 'plot_utils.py'>

# %%
df.filter(regex='spaceview')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 28112 entries, 2011-04-01 00:00:01.978000 to 2011-04-01 01:00:00.234000
# Data columns (total 1 columns):
# is_spaceview    28112  non-null values
# dtypes: bool(1)

# %%
dfnow = df[df.calib_block_labels==3]

# %%
dfnow
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 736 entries, 2011-04-01 00:27:04.016000 to 2011-04-01 00:28:38.097000
# Columns: 252 entries, sclk to is_calib
# dtypes: bool(6), float64(241), int32(4), int64(1)

# %%
ts = dfnow[dfnow.is_moving]['a6_11']

# %%
newdf = pd.DataFrame(index=dfnow.index)

# %%
newdf['moving'] = ts

# %%
newdf['spaceview'] = dfnow[dfnow.is_spaceview]['a6_11']

# %%
det = 'a6_11'

# %%
newdf['bbview'] = dfnow[dfnow.is_bbview][det]

# %%
newdf['stview'] = dfnow[dfnow.is_stview][det]

# %%
newdf.plot(style='.')

# %%
newdf = dfnow[df.is_moving | df.is_bbview | df.is_stview | df.is_spaceview][det]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-be05652cbf25> in <module>()
# ----> 1 newdf.columns
#
# AttributeError: 'TimeSeries' object has no attribute 'columns'
