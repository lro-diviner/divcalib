# %%
from diviner import file_utils as fu
from diviner import calib
from diviner.get_divdata import get_divdata

# %%
tstr = '2011061009'
df = fu.get_clean_l1a(tstr)
divdata = get_divdata(tstr, 6, 11)
# Out:
# Calling
#  tcsh -c '/u/marks/luner/c38/rel/divdata daterange=2011061009 clat=-90,90 c=6,6 det=11,11|/u/marks/luner/pipes/rel/pextract extract=year,month,date,hour,minute,second,jdate,c,det,clat,clon,radiance,tb|/u/marks/luner/pipes/rel/pprint titles=0 > /raid1/maye/divdata/2011061009_6-6_11-11_divdata.tab'
# Created text file /raid1/maye/divdata/2011061009_6-6_11-11_divdata.tab
# Size: 7221270
# Pandas parsing...
# Removing temporary text file
#  /raid1/maye/divdata/2011061009_6-6_11-11_divdata.tab

# %%
rdr2 = calib.Calibrator(df)
rdr2.calibrate()
# Out:
# WARNING:root:No caldata in calib_label at 2011-06-10 09:00:00.344000.  Found only 16 moving samples.

# %%
rdr2.Tb.a6_11.ix[:1000].plot()

# %%
divdata['2011-06-10 09:00:32':'2011-06-10 09:00:33']
# Out:
#                                      jdate  c  det       clat        clon  \
# 2011-06-10 09:00:32.088000  2455722.875371  6   11 -61.979679  176.850510
# 2011-06-10 09:00:32.216000  2455722.875373  6   11 -61.986401  176.850739
# 2011-06-10 09:00:32.345000  2455722.875374  6   11 -61.993130  176.850967
# 2011-06-10 09:00:32.472000  2455722.875376  6   11 -61.999840  176.851196
# 2011-06-10 09:00:32.600000  2455722.875377  6   11 -62.006569  176.851425
# 2011-06-10 09:00:32.729000  2455722.875379  6   11 -62.013290  176.851669
# 2011-06-10 09:00:32.857000  2455722.875380  6   11 -62.020012  176.851898
# 2011-06-10 09:00:32.985000  2455722.875382  6   11 -62.026730  176.852127
#
#                             radiance          tb
# 2011-06-10 09:00:32.088000    0.1266   93.564003
# 2011-06-10 09:00:32.216000    0.1948   99.011002
# 2011-06-10 09:00:32.345000    0.1675   97.042999
# 2011-06-10 09:00:32.472000    0.2085   99.915001
# 2011-06-10 09:00:32.600000    0.1948   99.011002
# ...
