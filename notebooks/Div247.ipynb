# %%
from diviner import file_utils as fu

# %%
pump = fu.Div247DataPump('2013052119')

# %%
pump.fnames
# Out:
# ['/luna1/marks/div247/201305/2013052119.div247']

# %%
df = pump.get_n_hours_from_t(1,0)
# Out:
# 2013052119.div247

# %%
df.ix['2013-05-21 19:49':'2013-05-21 19:52'].fpb_temp.dropna()
# Out:
# 2013-05-21 19:49:01.340999    305.252
# 2013-05-21 19:49:03.388999    305.258
# 2013-05-21 19:49:05.437000    305.252
# 2013-05-21 19:49:07.485000    305.246
# 2013-05-21 19:49:09.532999    305.249
# 2013-05-21 19:49:11.580999    305.252
# 2013-05-21 19:49:13.628999    305.246
# 2013-05-21 19:49:15.676999    305.243
# 2013-05-21 19:49:17.725000    305.243
# 2013-05-21 19:49:19.772999    305.246
# 2013-05-21 19:49:21.821999    305.246
# 2013-05-21 19:49:23.870000    305.243
# 2013-05-21 19:49:25.917999    305.246
# 2013-05-21 19:49:27.966000    305.243
# 2013-05-21 19:49:30.013999    305.246
# ...
# 2013-05-21 19:52:30.239999    305.264
# 2013-05-21 19:52:32.287999    305.270
# 2013-05-21 19:52:34.335999    305.276
# 2013-05-21 19:52:36.384000    305.276
# 2013-05-21 19:52:38.432000    305.276
# 2013-05-21 19:52:40.479999    305.267
# 2013-05-21 19:52:42.527999    305.267
# 2013-05-21 19:52:44.576000    305.257
# 2013-05-21 19:52:46.624000    305.266
# ...

# %%
df.fpb_temp.plot(style='k.-')

# %%
pd.rolling_mean?

# %%
fpb = df.fpa_temp.copy()

# %%
temps = fpb.dropna()

# %%
temps.plot()

# %%
pd.rolling_std(temps,100).plot()
