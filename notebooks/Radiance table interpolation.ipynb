# %%
import pandas as pd
import diviner as div
from diviner import calib as c
import sys
reload(c)
from scipy.interpolate import InterpolatedUnivariateSpline as ISpline

# %%
t2nrad = pd.read_pickle('../data/T_to_Normalized_Radiance.df')

# %%
temps = t2nrad.index

# %%
t2nrad = t2nrad.convert_objects()

# %%
t2nrad.dtypes
# Out:
# Channels
# 3           float64
# 4           float64
# 5           float64
# 6           float64
# 7           float64
# 8           float64
# 9           float64
# dtype: object

# %%
data = t2nrad[6]

# %%
temps = temps.astype('float')

# %%
from scipy.interpolate import UnivariateSpline as ipolator

# %%
yn = ipolator(data.values, temps.values,s=5, k=1)
yn2 = ipolator(data.values, temps.values, s=0.0, k=1)
fig, ax = subplots()
plot(data, temps, 'b.')
plot(data, yn(data), 'g-')
plot(data, yn2(data), 'c--')
# ax.set_xlim([0.004, 0.007])
# ax.set_ylim([95, 110])

# %%
deriv1 = data.diff()
deriv2 = deriv1.diff()

# %%
deriv1.size
# Out:
# 880

# %%
plot(deriv2, temps)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clf()
plot(temps,data,'k+',markeredgewidth=3,markersize=15,label='data')
grid()

# %% [markdown]
# lots of testing provided that the default cubic spline is best (i.e. k=3, default value for ISpline)

# %%
f = ISpline(temps,data)
plot(xs,f(xs),'.',markersize=10)

# %%
t2nrad.columns
# Out:
# Int64Index([3, 4, 5, 6, 7, 8, 9], dtype=int64)

# %%
l = []

# %%
temps = t2nrad.index*100
newtemps = arange(-45000,45000)

# %%
for col in t2nrad.columns:
    data = t2nrad[col]
    f = ISpline(temps,data)
    newdata = f(newtemps)
    l.append(pd.Series(newdata, index=newtemps,name=col))

# %%
newt2nrad = pd.concat(l,axis=1)

# %%
newt2nrad.plot()
xlabel('T [K]')
ylabel('Radiance')
title('T to Rad conversion functions')

# %%
newt2nrad.save('Ttimes100_to_Radiance.df')

# %%
newt2nrad
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90000 entries, -45000 to 44999
# Data columns (total 7 columns):
# 3    90000  non-null values
# 4    90000  non-null values
# 5    90000  non-null values
# 6    90000  non-null values
# 7    90000  non-null values
# 8    90000  non-null values
# 9    90000  non-null values
# dtypes: float64(7)
