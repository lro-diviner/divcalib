# %%
import pandas as pd
import diviner as div
import calib as c
import sys
from scipy import ndimage as nd
reload(c)
# Out:
# <module 'calib' from 'calib.py'>

# %%
if sys.platform == 'darwin':
    divcal = c.DivCalib(div.read_div_data("./df_by_2.h5"))
else:
    divcal = c.DivCalib(div.read_div_data('/luna1/maye/2009072000.h5'))

# %%
clf()

# %%
for i in range(8):
  for ch in [1,9]:
    df = divcal.timed[divcal.timed.c==ch]
    t = df.index.unique()[i]
    print df.clat[t].diff()
    plot(df.det[t],df.clat[t],'.-')
    #df.ix[0].plot('det','clat')
# Out:
# 2009-07-20 00:00:00.045000        NaN
# 2009-07-20 00:00:00.045000   -0.00016
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00016
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000    0.00182
# Name: clat
# 2009-07-20 00:00:00.045000        NaN
# 2009-07-20 00:00:00.045000    0.00009
# 2009-07-20 00:00:00.045000   -0.00032
# ...

# %%
ylabel('clat for Ch1 and Ch9')
xlabel('Detector no')
title('scalt: 115')

# %%
for ch in range(1,10):
    df = divcal.timed[divcal.timed.c==ch]
    t = df.index.unique()[0]
    print ch
    print df.clat[t].diff().values
    plot(df.det[t],df.clat[t],'.-',label='A: '+str(ch))
    #df.ix[0].plot('det','clat')
# Out:
# 1
# [     nan -0.00016 -0.00015 -0.00015 -0.00016 -0.00015 -0.00015 -0.00014
#  -0.00015 -0.00014 -0.00015 -0.00014 -0.00014 -0.00013 -0.00014 -0.00014
#  -0.00013 -0.00014 -0.00013 -0.00013  0.00182]
# 2
# [             nan  -1.50000000e-04  -1.50000000e-04  -1.50000000e-04
#   -1.40000000e-04  -2.00000000e-05  -2.70000000e-04  -1.50000000e-04
#   -1.50000000e-04  -1.30000000e-04  -1.50000000e-04  -1.30000000e-04
#   -1.50000000e-04  -1.30000000e-04  -2.80000000e-04  -2.70000000e-04
#   -3.40000000e-04  -1.40000000e-04  -1.30000000e-04  -1.40000000e-04
#   -1.30000000e-04]
# 3
# [     nan -0.00013 -0.00014 -0.00014 -0.00015 -0.00014 -0.00015 -0.00014
#  -0.00014 -0.00014 -0.00015 -0.00013 -0.00013 -0.00015 -0.00014 -0.00027
#  -0.00028 -0.00014 -0.00015 -0.00014 -0.00013]
# 4
# [             nan  -1.30000000e-04  -1.40000000e-04  -1.30000000e-04
#   -6.00000000e-05  -1.40000000e-04  -8.00000000e-05  -1.30000000e-04
# ...

# %%
legend(loc='best')

# %%
ch3.clat[ch3.index[0]].diff()
# Out:
# 2009-07-20 00:00:00.045000        NaN
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00027
# 2009-07-20 00:00:00.045000   -0.00028
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00013
# Name: clat

# %%
ch3.clat[ch3.index[0]].diff()
# Out:
# 2009-07-20 00:00:00.045000        NaN
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00013
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00027
# 2009-07-20 00:00:00.045000   -0.00028
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00015
# 2009-07-20 00:00:00.045000   -0.00014
# 2009-07-20 00:00:00.045000   -0.00013
# Name: clat

# %%
clon = df.clon

# %%
clat = clat.dropna()

# %%
clon = clon.dropna()

# %%
clat
# Out:
# 0     5.01913
# 1     5.01897
# 2     5.01882
# 3     5.01867
# 4     5.01851
# 5     5.01836
# 6     5.01821
# 7     5.01807
# 8     5.01792
# 9     5.01778
# 10    5.01763
# 11    5.01749
# 12    5.01735
# 13    5.01722
# 14    5.01708
# ...
# 2599491   -88.69547
# 2599492   -88.69662
# 2599493   -88.69775
# 2599494   -88.69887
# 2599495   -88.69991
# 2599496   -88.70104
# 2599497   -88.70210
# 2599498   -88.70321
# 2599499   -88.70419
# 2599500   -88.70542
# 2599501   -88.70639
# 2599502   -88.70734
# 2599503   -88.70837
# 2599504   -88.70940
# 2599505   -88.71082
# Name: clat, Length: 2399922

# %%
plot(clat,clon)

# %%
dfview = df[:189]

# %%
vals, indexes = np.unique(dfview.clat,return_index=True)

# %%
indexes.sort()

# %%
dfview.clat[110:130]
# Out:
# 2009-07-20 00:00:00.045000    4.75912
# 2009-07-20 00:00:00.045000    4.75919
# 2009-07-20 00:00:00.045000    4.75906
# 2009-07-20 00:00:00.045000    4.75893
# 2009-07-20 00:00:00.045000    4.75913
# 2009-07-20 00:00:00.045000    4.75885
# 2009-07-20 00:00:00.045000    4.75885
# 2009-07-20 00:00:00.045000    4.75871
# 2009-07-20 00:00:00.045000    4.75857
# 2009-07-20 00:00:00.045000    4.75844
# 2009-07-20 00:00:00.045000    4.75815
# 2009-07-20 00:00:00.045000    4.75788
# 2009-07-20 00:00:00.045000    4.75773
# 2009-07-20 00:00:00.045000    4.75757
# 2009-07-20 00:00:00.045000    4.75742
# 2009-07-20 00:00:00.045000    4.75728
# 2009-07-20 00:00:00.045000    5.02775
# 2009-07-20 00:00:00.045000    5.02760
# 2009-07-20 00:00:00.045000    5.02745
# 2009-07-20 00:00:00.045000    5.02730
# Name: clat

# %%
for ch in range(1,10):
    cdf = df[df.c==ch][231:252]
    print cdf.clat.unique().size
# Out:
# 21
# 21
# 21
# 21
# 20
# 20
# 20
# 21
# 21

# %%
ch6 = df[df.c==6]

# %%
ch7[:21].plot('det','clat',style='k*')

# %%
ch6.clon[210:231].diff()
# Out:
# 2009-07-20 00:00:01.324000        NaN
# 2009-07-20 00:00:01.324000   -0.01144
# 2009-07-20 00:00:01.324000   -0.01248
# 2009-07-20 00:00:01.324000   -0.01315
# 2009-07-20 00:00:01.324000   -0.01178
# 2009-07-20 00:00:01.324000   -0.01349
# 2009-07-20 00:00:01.324000   -0.01212
# 2009-07-20 00:00:01.324000   -0.01279
# 2009-07-20 00:00:01.324000   -0.01245
# 2009-07-20 00:00:01.324000   -0.01281
# 2009-07-20 00:00:01.324000   -0.01346
# 2009-07-20 00:00:01.324000   -0.01212
# 2009-07-20 00:00:01.324000   -0.01349
# 2009-07-20 00:00:01.324000   -0.01178
# 2009-07-20 00:00:01.324000   -0.01178
# 2009-07-20 00:00:01.324000   -0.01348
# 2009-07-20 00:00:01.324000   -0.01145
# 2009-07-20 00:00:01.324000   -0.01346
# 2009-07-20 00:00:01.324000   -0.01349
# 2009-07-20 00:00:01.324000   -0.01214
# 2009-07-20 00:00:01.324000   -0.01178
# Name: clon

# %%
ch7 = df[df.c==7]

# %%
ch7[['det','clat']][21:42]
# Out:
#                             det     clat
# 2009-07-20 00:00:00.173000    1  5.02131
# 2009-07-20 00:00:00.173000    2  5.02116
# 2009-07-20 00:00:00.173000    3  5.02101
# 2009-07-20 00:00:00.173000    4  5.02086
# 2009-07-20 00:00:00.173000    5  5.01985
# 2009-07-20 00:00:00.173000    6  5.02004
# 2009-07-20 00:00:00.173000    7  5.01915
# 2009-07-20 00:00:00.173000    8  5.01901
# 2009-07-20 00:00:00.173000    9  5.01886
# 2009-07-20 00:00:00.173000   10  5.01892
# 2009-07-20 00:00:00.173000   11  5.01878
# 2009-07-20 00:00:00.173000   12  5.01878
# 2009-07-20 00:00:00.173000   13  5.01865
# 2009-07-20 00:00:00.173000   14  5.01852
# 2009-07-20 00:00:00.173000   15  5.01832
# 2009-07-20 00:00:00.173000   16  5.01792
# 2009-07-20 00:00:00.173000   17  5.01759
# 2009-07-20 00:00:00.173000   18  5.01745
# 2009-07-20 00:00:00.173000   19  5.01733
# 2009-07-20 00:00:00.173000   20  5.01720
# 2009-07-20 00:00:00.173000   21  5.01707

# %%
ylabel('Channel 7 clat for 2 consecutive frames')

# %%
clf()
for ch in range(1,7):
    cdf = df[df.c==ch]
    plot(cdf[:21].det,cdf[:21].clon,'.-',label='A:Ch '+str(ch))

# %%
for ch in range(7,10):
    cdf = df[df.c==ch]
    plot(cdf[:21].det,cdf[:21].clon,'.--',label='B:Ch '+str(ch))

# %%
legend(loc='best')

# %%
clf()
ch7[:21].plot('det','clat',label='ch7')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-0f4833abff5e> in <module>()
#       1 clf()
# ----> 2 ch7[:21].plot('det','clat',label='ch7')
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/pandas-0.10.0b1-py2.7-macosx-10.5-x86_64.egg/pandas/tools/plotting.pyc in plot_frame(frame, x, y, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, style, title, xlim, ylim, logy, xticks, yticks, kind, sort_columns, fontsize, secondary_y, **kwds)
#    1419                            grid=grid, logy=logy, secondary_y=secondary_y,
#    1420                            title=title, figsize=figsize, fontsize=fontsize,
# -> 1421                            **kwds)
#    1422
#    1423     plot_obj = klass(frame, kind=kind, subplots=subplots, rot=rot,
#
# TypeError: plot_series() got multiple values for keyword argument 'label'

# %%
legend()

# %%
pd.__version__
# Out:
# '0.10.0b1'

# %%
cols = df.columns
for col in cols:
    size = df[col][:189].unique().size
    if size != 1:
        print col
# Out:
# c
# det
# vlookx
# vlooky
# vlookz
# radiance
# tb
# clat
# clon
# cemis
# csunzen
# csunazi
# cloctime
# counts

# %%
clf()
for ch in range(1,10):
    cdf = df[df.c==ch]
    print ch
    plot(cdf[:21].csunzen,'*',label='ch '+str(ch))
ax = gca()
ax.set_xlim([-1,22])
grid()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
legend(loc='best')

# %%
csunzen = df.csunzen[:189]

# %%
csunzen.unique().size
# Out:
# 186

# %%
plot(csunzen,'*')
