# %%
import pandas as pd
import file_utils as fu
import calib as c
reload(fu)
reload(c)
# Out:
# <module 'calib' from 'calib.py'>

# %%
pump = fu.Div247DataPump("20110416")

# %%
df = pump.get_n_hours(2)
# Out:
#  [                       0%                       ]
#  [*********************100%***********************]  2 of 2 complete

# %%
calib = c.Calibrator(df)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-71-d8c34923254e> in <module>()
# ----> 1 calib = c.Calibrator(df)
#
# /raid1/u/paige/maye/src/diviner/calib.py in __init__(self, df)
#     253
#     254         # get the normalized radiance for the interpolated bb temps
# --> 255         self.get_RBB()
#     256
#     257         ## drop these columns as they are not required anymore (i think)
#
# /raid1/u/paige/maye/src/diviner/calib.py in get_RBB(self)
#     363             # the bb temperatures
#     364             print RBBs.head()
# --> 365             self.df['RBB_'+channel] = pd.Series(RBBs,index = bbtemps.index)
#     366         return self.RBB
#     367
#
# /usr/local/epd/lib/python2.7/site-packages/pandas/core/series.pyc in __new__(cls, data, index, dtype, name, copy)
#     403                 index = data.index
#     404             else:
# --> 405                 data = data.reindex(index).values
#     406         elif isinstance(data, dict):
#     407             if index is None:
#
# /usr/local/epd/lib/python2.7/site-packages/pandas/core/series.pyc in reindex(self, index, method, level, fill_value, limit, copy)
#    2480
#    2481         new_index, indexer = self.index.reindex(index, method=method,
# -> 2482                                                 level=level, limit=limit)
#    2483         new_values = com.take_1d(self.values, indexer, fill_value=fill_value)
#    2484         return Series(new_values, index=new_index, name=self.name)
#
# /usr/local/epd/lib/python2.7/site-packages/pandas/core/index.pyc in reindex(self, target, method, level, limit)
#     891             else:
#     892                 indexer = self.get_indexer(target, method=method,
# --> 893                                            limit=limit)
#     894         return target, indexer
#     895
#
# /usr/local/epd/lib/python2.7/site-packages/pandas/core/index.pyc in get_indexer(self, target, method, limit)
#     807             this = self.astype(object)
#     808             target = target.astype(object)
# --> 809             return this.get_indexer(target, method=method, limit=limit)
#     810
#     811         if not self.is_unique:
#
# /usr/local/epd/lib/python2.7/site-packages/pandas/core/index.pyc in get_indexer(self, target, method, limit)
#     810
#     811         if not self.is_unique:
# --> 812             raise Exception('Reindexing only valid with uniquely valued Index '
#     813                             'objects')
#     814
#
# Exception: Reindexing only valid with uniquely valued Index objects
# 30308    1.064819
# 30308    1.064819
# 30308    1.064819
# 30308    1.064819
# 30308    1.064819
# Name: 3, Dtype: float64

# %%
calib.df.bb_2_temp_interp.plot(linewidth=3)
calib.df.bb_2_temp.plot(style='r.',)
display(gcf())

# %%
calib.RBB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56240 entries, 2011-04-16 00:00:01.296999 to 2011-04-16 02:00:00.007000
# Data columns:
# a3    56240  non-null values
# a4    56240  non-null values
# a5    56240  non-null values
# a6    56240  non-null values
# b1    56240  non-null values
# b2    56240  non-null values
# b3    56240  non-null values
# dtypes: float64(7)

# %%
calib.RBB.a3.plot()
