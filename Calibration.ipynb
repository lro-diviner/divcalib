# %%
import diviner as div
import calib as c

# %%
df = div.read_div_data('/luna1/maye/2009072000.h5')

# %%
reload(c)
# Out:
# <module 'calib' from 'calib.py'>

# %%
c.plot_calib_data(df,3,11)

# %%
ax = cdet.counts[cdet.el_cmd==80].plot(style='ko')
q
# Out:
# (23860, 23885)
